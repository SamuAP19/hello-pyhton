# %% [markdown]
# # Object-Oriented Programming Exercises

# %% [markdown]
# ## 1. Secure Data Logger (Encapsulation + Static/Class Methods)

# %% [markdown]
# **Goal:** Build a secure logging system that hides sensitive data.
#
# **Instructions:**
# 1. Create a `LogEntry` class with protected `_timestamp`, `_message`, and private `__level`.
# 2. Create a `SecureLogger` class with private class attribute `__logs`, class methods, and static methods.
# 3. Prevent external access to private data while allowing controlled log display.

# %%
import datetime
# use datetime.datetime.now() to get the current time
class LogEntry:
    def __init__(self, message, level):
        self._timestamp = datetime.datetime.now()
        self._message = message
        self.__level = level
    def display(self):
        msg = self._message
        if self.__level == "HIGH":
            msg = "*" * len(self._message)
            return f"the {self._message}, with level {self.__level}, at {self._timestamp}"
        
"""
def display(self):
    msg = self._message
    if self.__level == "HIGH"
    msg = "*" * len(self._message)
"""

#association, composition, etc; its different of what is done here. Composition is if mother removed the others are deleted, the aggregation is create obj and agregate to a major class. 
#in here we arent creating, we are embedding
class SecureLogger:
    __logs =[]
    @classmethod
    def users_login(cls,message, level):
        logentry = LogEntry(message,level)
        cls.__logs.append(logentry)
    @staticmethod
    def get_time(time):
        time = LogEntry(time)
        print(f"{time}")

print(SecureLogger.users_login("Hello", "HIGH"))
# Out:
# None

# %% [markdown]
# ## 2. Robotic Assembly Line (Composition + Aggregation + Inheritance)

# %% [markdown]
# **Goal:** Simulate a factory that assembles robots from components.
#
# **Instructions:**
# 1. Base `Component` class → derived `Motor`, `Sensor`, `Frame`.
# 2. `Robot` class → composes multiple components.
# 3. `AssemblyLine` → aggregates multiple robots.
# 4. Implement cost calculations and summaries.

# %%
# Your implementation here

# %% [markdown]
# ## 3. Research Network (Inheritance + Encapsulation)

# %% [markdown]
# **Goal:** Model a research organization with people, researchers, and lab directors.
#
# **Instructions:**
# 1. Base `Person` → public `name`, protected `_email`, private `__id`.
# 2. Subclasses: `Researcher`, `LabDirector`.
# 3. Use class methods to manage registration and encapsulation for sensitive fields.

# %%
# Your implementation here

# %% [markdown]
# ## 4. Smart Banking System (Polymorphism + Encapsulation + Class Methods)

# %% [markdown]
# **Goal:** Implement a secure banking system with polymorphism.
#
# **Instructions:**
# 1. Abstract base `Account` with private `__balance`.
# 2. Derived classes: `SavingsAccount`, `CheckingAccount`.
# 3. `Bank` class with class and static methods for account management.

# %%
# Your implementation here
